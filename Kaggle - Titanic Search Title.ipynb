# %%
import pandas as pd
import numpy as np
import csv as csv
import os, re

DIR_PATH= "/vagrant/titanic/"

# %%
# TRAIN DATA
df = pd.read_csv(os.path.join(DIR_PATH, 'train.csv'), header=0)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
def search_title(name):
    match = re.search(r'\w+\.', name)
    if match:    
        return match.group()
    else:
        return ''

# %%
df['Title'] = df['Name'].map(search_title)
set_title = set(df['Title'])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr.
# 1      0          PC 17599  71.2833   C85        C   Mrs.
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss.
# 3      0            113803  53.1000  C123        S   Mrs.
# ...

# %%
print df[df.Title == 'Mr.'].Age.mean()
print df[df.Title == 'Mr.']['Age'].median()

df_title = pd.DataFrame(columns=['Title', 'Mean Age', 'Median Age', 'Survived', 'Total', '%'])
[df.Pclass == 3]
for title in set_title:
    #pd_title = pd_title.append(pd.Series([title, df[df.Title == title].Age.mean(), df[df.Title == title].Age.median()]), ignore_index=True)
    df_title = df_title.append({'Title': title,
                                'Mean Age': df[df.Title == title].Age.mean(),
                                'Median Age' : df[df.Title == title].Age.median(),
                                'Survived': df[df.Title == title].Survived.sum(),
                                'Total': df[df.Title == title].Survived.count(),
                                '%': (df[df.Title == title].Survived.sum() / float(df[df.Title == title].Survived.count()))*100
                                #, 'Count' : df[df.Title == title].Title.value_counts()
                                }, ignore_index=True,
                               )
df_title.sort(columns=['%'], ascending=False)
df_title
# Out:
# 32.3680904523
# 30.0
#         Title   Mean Age  Median Age  Survived  Total           %
# 0       Miss.  21.773973        21.0       127    182   69.780220
# 1        Mme.  24.000000        24.0         1      1  100.000000
# 2        Rev.  43.166667        46.5         0      6    0.000000
# 3   Countess.  33.000000        33.0         1      1  100.000000
# 4   Jonkheer.  38.000000        38.0         0      1    0.000000
# 5        Sir.  49.000000        49.0         1      1  100.000000
# 6       Mlle.  24.000000        24.0         2      2  100.000000
# 7        Mrs.  35.898148        35.0        99    125   79.200000
# 8       Capt.  70.000000        70.0         0      1    0.000000
# 9        Col.  58.000000        58.0         1      2   50.000000
# 10        Ms.  28.000000        28.0         1      1  100.000000
# 11        Mr.  32.368090        30.0        81    517   15.667311
# 12      Lady.  48.000000        48.0         1      1  100.000000
# ...

# %%
fig = plt.figure(figsize=(18,15), dpi=1600)
a_bar = 0.7
color_bar = '#99FF66'

plt.subplot2grid((2,3),(0,0))
df.Title.value_counts().plot(kind="barh", color=color_bar, alpha=a_bar)
plt.title("Title distribution")
plt.ylabel("Count")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Title          891 non-null object
# dtypes: float64(2), int64(5), object(6)

# %%
df = df.drop(['Cabin', 'Embarked'], axis=1)

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
# Make a copy of Age
df['AgeFill'] = df['Age']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Title          891 non-null object
# AgeFill        714 non-null float64
# dtypes: float64(3), int64(5), object(4)

# %%
df[df.AgeFill.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
for title in set_title:
    df.loc[ (df.Age.isnull()) & (df.Title==title), 'AgeFill'] = df_title[ (df_title.Title==title) ]['Median Age'].iget(0)

# %%
df_title
# Out:
#         Title   Mean Age  Median Age  Survived  Total           %
# 0       Miss.  21.773973        21.0       127    182   69.780220
# 1        Mme.  24.000000        24.0         1      1  100.000000
# 2        Rev.  43.166667        46.5         0      6    0.000000
# 3   Countess.  33.000000        33.0         1      1  100.000000
# 4   Jonkheer.  38.000000        38.0         0      1    0.000000
# 5        Sir.  49.000000        49.0         1      1  100.000000
# 6       Mlle.  24.000000        24.0         2      2  100.000000
# 7        Mrs.  35.898148        35.0        99    125   79.200000
# 8       Capt.  70.000000        70.0         0      1    0.000000
# 9        Col.  58.000000        58.0         1      2   50.000000
# 10        Ms.  28.000000        28.0         1      1  100.000000
# 11        Mr.  32.368090        30.0        81    517   15.667311
# 12      Lady.  48.000000        48.0         1      1  100.000000
# ...

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 10 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Fare           891 non-null float64
# Title          891 non-null object
# AgeFill        891 non-null float64
# dtypes: float64(2), int64(5), object(3)

# %%
df = df.drop(['Age', 'Ticket'], axis=1)
