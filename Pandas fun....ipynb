# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three']*6,
                   'B' : ['A', 'B', 'C']*8,
                   'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] *4,
                   'D' : np.random.randn(24),
                   'E' : np.random.randn(24),
                   'F' : [datetime.datetime(2014, i, 1) for i in range(1,13)] + [datetime.datetime(2014, i, 15) for i in range(1,13)]})

# %%
df
# Out:
#         A  B    C         D         E          F
# 0     one  A  foo  3.899267 -1.117483 2014-01-01
# 1     one  B  foo  0.889520  1.057058 2014-02-01
# 2     two  C  foo  0.150329  1.066783 2014-03-01
# 3   three  A  bar  0.472618 -2.867409 2014-04-01
# 4     one  B  bar  0.819429 -0.535579 2014-05-01
# 5     one  C  bar  0.977572  0.325323 2014-06-01
# 6     two  A  foo -0.534124  0.072134 2014-07-01
# 7   three  B  foo -0.391422  1.764014 2014-08-01
# 8     one  C  foo -0.233740 -1.447466 2014-09-01
# 9     one  A  bar -1.748353 -0.395751 2014-10-01
# 10    two  B  bar  1.376081  1.488347 2014-11-01
# 11  three  C  bar -0.384067 -0.284899 2014-12-01
# 12    one  A  foo  0.415365  2.017532 2014-01-15
# 13    one  B  foo  0.653047  0.734948 2014-02-15
# 14    two  C  foo -1.500651  1.330614 2014-03-15
# 15  three  A  bar -1.092422 -0.862347 2014-04-15
# 16    one  B  bar -0.346284  0.357448 2014-05-15
# 17    one  C  bar -0.535564 -1.432414 2014-06-15
# ...

# %%
print df.dtypes
print
print df.info()
print
print df.describe()
# Out:
# A            object
# B            object
# C            object
# D           float64
# E           float64
# F    datetime64[ns]
# dtype: object
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 0 to 23
# Data columns (total 6 columns):
# A    24 non-null object
# B    24 non-null object
# C    24 non-null object
# D    24 non-null float64
# E    24 non-null float64
# F    24 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(3)
# None
#
#                D          E
# count  24.000000  24.000000
# mean    0.201881  -0.053689
# std     1.138060   1.170106
# min    -1.748353  -2.867409
# 25%    -0.427097  -0.873298
# 50%     0.145718  -0.144420
# 75%     0.832677   0.815475
# max     3.899267   2.017532

# %%
df.head()
# Out:
#        A  B    C         D         E          F
# 0    one  A  foo  3.899267 -1.117483 2014-01-01
# 1    one  B  foo  0.889520  1.057058 2014-02-01
# 2    two  C  foo  0.150329  1.066783 2014-03-01
# 3  three  A  bar  0.472618 -2.867409 2014-04-01
# 4    one  B  bar  0.819429 -0.535579 2014-05-01

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'], aggfunc=sum)
# Out:
# C             bar       foo
# A     B
# one   A -0.875932  4.314632
#       B  0.473144  1.542567
#       C  0.442007  0.997457
# three A -0.619804       NaN
#       B       NaN  0.077506
#       C -0.596104       NaN
# two   A       NaN -0.393017
#       B  0.833005       NaN
#       C       NaN -1.350321

# %%
df = pd.read_csv("/vagrant/titanic/train.csv")
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
pd.pivot_table(df, values='Survived', index=['Sex', 'Pclass'], aggfunc=np.mean)
# Out:
# Sex     Pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: Survived, dtype: float64

# %%
df.T.head()
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
#
#                                 2    \
# PassengerId                       3
# Survived                          1
# Pclass                            3
# Name         Heikkinen, Miss. Laina
# Sex                          female
#
#                                                       3    \
# PassengerId                                             4
# ...

# %%
print df
print "result"
df.loc[0, 'B'] = 55
for row in df.B:
    row = 100
print df
# Out:
#      A   B  C
# 0    1  55  5
# 1  100   3  1
# 2    1   1  1
# result
#      A   B  C
# 0    1  55  5
# 1  100   3  1
# 2    1   1  1

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
print ts
ts = ts.cumsum()
ts
# Out:
# 2000-01-01   -2.078822
# 2000-01-02   -0.377645
# 2000-01-03   -0.248093
# 2000-01-04   -0.994463
# 2000-01-05    0.699074
# 2000-01-06   -0.656621
# 2000-01-07    0.091949
# 2000-01-08   -0.078489
# 2000-01-09   -0.005159
# 2000-01-10    0.143097
# 2000-01-11   -1.089234
# 2000-01-12    0.963000
# 2000-01-13   -0.796568
# 2000-01-14   -0.108379
# 2000-01-15   -0.880547
# ...
# 2002-09-12    0.938310
# 2002-09-13   -0.950673
# 2002-09-14   -0.117563
# 2002-09-15   -0.657278
# 2002-09-16    1.164938
# 2002-09-17   -0.490454
# 2002-09-18    0.051843
# 2002-09-19   -0.149559
# 2002-09-20   -0.238745
# 2002-09-21   -0.256587
# 2002-09-22   -0.261885
# 2002-09-23   -1.294739
# 2002-09-24   -1.230120
# 2002-09-25    0.365046
# 2002-09-26   -1.010378
# Freq: D, Length: 1000
# 2000-01-01   -2.078822
# 2000-01-02   -2.456468
# 2000-01-03   -2.704561
# 2000-01-04   -3.699024
# 2000-01-05   -2.999949
# 2000-01-06   -3.656570
# 2000-01-07   -3.564621
# 2000-01-08   -3.643111
# ...

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(100, 4), index=ts.index[:100], columns=['A', 'B', 'C', 'D'])
df = df.cumsum()

# %%
plt.figure();df.plot();plt.legend(loc='best')

# %%
df = pd.DataFrame([[1,10,5], [100,3,1], [1,1,1]], columns=['A', 'B', 'C'])
print df
print
print df.cumsum()
# Out:
#      A   B  C
# 0    1  10  5
# 1  100   3  1
# 2    1   1  1
#
#      A   B  C
# 0    1  10  5
# 1  101  13  6
# 2  102  14  7

# %%
df = pd.DataFrame(np.random.randint(-100, 100, [10,5]))
df
# Out:
#     0   1   2   3   4
# 0   2  -1 -27 -37 -19
# 1  96 -39  18 -91 -16
# 2 -18  65   7 -85  40
# 3 -16 -69  -5  33  -4
# 4   6  51  63  44  49
# 5  56 -97  75 -66 -91
# 6  31 -87  92  44 -50
# 7 -42  83 -10 -97 -78
# 8  20 -86  40  68 -72
# 9 -31  10  44  51  70

# %%
df.append(pd.Series([1,2,3,4,5]),ignore_index=True)
# Out:
#      0   1   2   3   4
# 0    2  -1 -27 -37 -19
# 1   96 -39  18 -91 -16
# 2  -18  65   7 -85  40
# 3  -16 -69  -5  33  -4
# 4    6  51  63  44  49
# 5   56 -97  75 -66 -91
# 6   31 -87  92  44 -50
# 7  -42  83 -10 -97 -78
# 8   20 -86  40  68 -72
# 9  -31  10  44  51  70
# 10   1   2   3   4   5

# %%
s1 = pd.Series([1,2,3])
s2 = pd.Series([4,5,6])
s1 + s2
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64
